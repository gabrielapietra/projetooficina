# %%
import pyaudio
import struct
import numpy as np
import matplotlib.pyplot as plt
import librosa
import librosa.display as ld
from IPython.display import Audio
import time
import wave
import os
import logging

# %matplotlib tk

# %% [markdown]
# CHUNK = how much audio gonna be processed at a time / how many audio samples per frame (1024 * 4)
#
# FORMAT = pyaudio.paInt16 (bytes per sample)
#
# CHANNELS =
#
# RATE = samples per second (fs)

# %%
#Audio(filename='DerezzedShort5.wav')

# %%
#data, fs = librosa.load('DerezzedShort5.wav', sr=None)

# %% [markdown]
# def play_audio_file(fname='DerezzedShort5.wav'):
#     """Simple callback function to play a wave file.    """
#     song_wav = wave.open(fname, 'rb')
#     song_data = song_wav.readframes(song_wav.getnframes())
#     audio = pyaudio.PyAudio()
#     stream_out = audio.open(
#         format=audio.get_format_from_width(song_wav.getsampwidth()),
#         channels=song_wav.getnchannels(),
#         rate=song_wav.getframerate(), input=True, output=True)
#     stream_out.start_stream()
#     stream_out.write(song_data)
#     #time.sleep(0.2)
#     stream_out.stop_stream()
#     stream_out.close()
#     audio.terminate()

# %%
#play_audio_file('DerezzedShort5.wav')

# %%
song_wav = wave.open('DerezzedShort5.wav', 'rb')
FORMAT = pyaudio.PyAudio().get_format_from_width(song_wav.getsampwidth())
CHANNELS = song_wav.getnchannels()
RATE = song_wav.getframerate()
CHUNK = song_wav.getnframes()
#CHUNK = song_wav.readframes(n_frames)

# %%
p = pyaudio.PyAudio()

stream = p.open(
    format = FORMAT,
    channels = CHANNELS,
    rate = RATE,
    input = True,
    output = True,
    frames_per_buffer = CHUNK
)

# %% [markdown]
# data = stream.read(CHUNK)
# #data_int = struct.unpack(str(CHUNK) + 'B', data)
# data_int
#
# fig, ax = plt.subplots()
#
# ax. plot(data_int, '-')

# %%
fig, ax = plt.subplots()

x = np.arange(0, 2*CHUNK, 2)
line, = ax.plot(x, np.random.rand(CHUNK))
ax.set_ylim(0,255)
ax.set_xlim(0,CHUNK)

while True:
    data = stream.read(CHUNK)
    data_int = np.array(struct.unpack(str(CHUNK * 4) + 'B', data), dtype='b')[::2]+127
    line.set_ydata(data_int)
    fig.canvas.draw()
    fig.canvas.flush_events()
# Out:
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "C:\Users\Dani\anaconda3\lib\tkinter\__init__.py", line 1892, in __call__
#     return self.func(*args)
#   File "C:\Users\Dani\anaconda3\lib\tkinter\__init__.py", line 814, in callit
#     func(*args)
#   File "C:\Users\Dani\anaconda3\lib\site-packages\matplotlib\backends\_backend_tk.py", line 253, in idle_draw
#     self.draw()
#   File "C:\Users\Dani\anaconda3\lib\site-packages\matplotlib\backends\backend_tkagg.py", line 9, in draw
#     super(FigureCanvasTkAgg, self).draw()
#   File "C:\Users\Dani\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py", line 407, in draw
#     self.figure.draw(self.renderer)
#   File "C:\Users\Dani\anaconda3\lib\site-packages\matplotlib\artist.py", line 41, in draw_wrapper
#     return draw(artist, renderer, *args, **kwargs)
#   File "C:\Users\Dani\anaconda3\lib\site-packages\matplotlib\figure.py", line 1863, in draw
#     mimage._draw_list_compositing_images(
#   File "C:\Users\Dani\anaconda3\lib\site-packages\matplotlib\image.py", line 131, in _draw_list_compositing_images
#     a.draw(renderer)
#   File "C:\Users\Dani\anaconda3\lib\site-packages\matplotlib\artist.py", line 41, in draw_wrapper
#     return draw(artist, renderer, *args, **kwargs)
#   File "C:\Users\Dani\anaconda3\lib\site-packages\matplotlib\cbook\deprecation.py", line 411, in wrapper
#     return func(*inner_args, **inner_kwargs)
#   File "C:\Users\Dani\anaconda3\lib\site-packages\matplotlib\axes\_base.py", line 2747, in draw
#     mimage._draw_list_compositing_images(renderer, self, artists)
#   File "C:\Users\Dani\anaconda3\lib\site-packages\matplotlib\image.py", line 131, in _draw_list_compositing_images
#     a.draw(renderer)
#   File "C:\Users\Dani\anaconda3\lib\site-packages\matplotlib\artist.py", line 41, in draw_wrapper
#     return draw(artist, renderer, *args, **kwargs)
#   File "C:\Users\Dani\anaconda3\lib\site-packages\matplotlib\lines.py", line 742, in draw
#     self.recache()
#   File "C:\Users\Dani\anaconda3\lib\site-packages\matplotlib\lines.py", line 662, in recache
#     self._xy = np.column_stack(np.broadcast_arrays(x, y)).astype(float)
#   File "<__array_function__ internals>", line 5, in broadcast_arrays
#   File "C:\Users\Dani\anaconda3\lib\site-packages\numpy\lib\stride_tricks.py", line 538, in broadcast_arrays
#     shape = _broadcast_shape(*args)
#   File "C:\Users\Dani\anaconda3\lib\site-packages\numpy\lib\stride_tricks.py", line 420, in _broadcast_shape
#     b = np.broadcast(*args[:32])
# ValueError: shape mismatch: objects cannot be broadcast to a single shape
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "C:\Users\Dani\anaconda3\lib\tkinter\__init__.py", line 1892, in __call__
#     return self.func(*args)
#   File "C:\Users\Dani\anaconda3\lib\site-packages\matplotlib\backends\_backend_tk.py", line 242, in resize
#     self.draw()
#   File "C:\Users\Dani\anaconda3\lib\site-packages\matplotlib\backends\backend_tkagg.py", line 9, in draw
#     super(FigureCanvasTkAgg, self).draw()
#   File "C:\Users\Dani\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py", line 407, in draw
#     self.figure.draw(self.renderer)
#   File "C:\Users\Dani\anaconda3\lib\site-packages\matplotlib\artist.py", line 41, in draw_wrapper
#     return draw(artist, renderer, *args, **kwargs)
#   File "C:\Users\Dani\anaconda3\lib\site-packages\matplotlib\figure.py", line 1863, in draw
#     mimage._draw_list_compositing_images(
#   File "C:\Users\Dani\anaconda3\lib\site-packages\matplotlib\image.py", line 131, in _draw_list_compositing_images
#     a.draw(renderer)
#   File "C:\Users\Dani\anaconda3\lib\site-packages\matplotlib\artist.py", line 41, in draw_wrapper
#     return draw(artist, renderer, *args, **kwargs)
#   File "C:\Users\Dani\anaconda3\lib\site-packages\matplotlib\cbook\deprecation.py", line 411, in wrapper
#     return func(*inner_args, **inner_kwargs)
#   File "C:\Users\Dani\anaconda3\lib\site-packages\matplotlib\axes\_base.py", line 2747, in draw
#     mimage._draw_list_compositing_images(renderer, self, artists)
#   File "C:\Users\Dani\anaconda3\lib\site-packages\matplotlib\image.py", line 131, in _draw_list_compositing_images
#     a.draw(renderer)
#   File "C:\Users\Dani\anaconda3\lib\site-packages\matplotlib\artist.py", line 41, in draw_wrapper
#     return draw(artist, renderer, *args, **kwargs)
#   File "C:\Users\Dani\anaconda3\lib\site-packages\matplotlib\lines.py", line 742, in draw
#     self.recache()
#   File "C:\Users\Dani\anaconda3\lib\site-packages\matplotlib\lines.py", line 662, in recache
#     self._xy = np.column_stack(np.broadcast_arrays(x, y)).astype(float)
#   File "<__array_function__ internals>", line 5, in broadcast_arrays
#   File "C:\Users\Dani\anaconda3\lib\site-packages\numpy\lib\stride_tricks.py", line 538, in broadcast_arrays
#     shape = _broadcast_shape(*args)
#   File "C:\Users\Dani\anaconda3\lib\site-packages\numpy\lib\stride_tricks.py", line 420, in _broadcast_shape
#     b = np.broadcast(*args[:32])
# ValueError: shape mismatch: objects cannot be broadcast to a single shape
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "C:\Users\Dani\anaconda3\lib\tkinter\__init__.py", line 1892, in __call__
#     return self.func(*args)
#   File "C:\Users\Dani\anaconda3\lib\tkinter\__init__.py", line 814, in callit
#     func(*args)
#   File "C:\Users\Dani\anaconda3\lib\site-packages\matplotlib\backends\_backend_tk.py", line 253, in idle_draw
#     self.draw()
#   File "C:\Users\Dani\anaconda3\lib\site-packages\matplotlib\backends\backend_tkagg.py", line 9, in draw
#     super(FigureCanvasTkAgg, self).draw()
#   File "C:\Users\Dani\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py", line 407, in draw
#     self.figure.draw(self.renderer)
#   File "C:\Users\Dani\anaconda3\lib\site-packages\matplotlib\artist.py", line 41, in draw_wrapper
#     return draw(artist, renderer, *args, **kwargs)
#   File "C:\Users\Dani\anaconda3\lib\site-packages\matplotlib\figure.py", line 1863, in draw
#     mimage._draw_list_compositing_images(
#   File "C:\Users\Dani\anaconda3\lib\site-packages\matplotlib\image.py", line 131, in _draw_list_compositing_images
#     a.draw(renderer)
#   File "C:\Users\Dani\anaconda3\lib\site-packages\matplotlib\artist.py", line 41, in draw_wrapper
#     return draw(artist, renderer, *args, **kwargs)
#   File "C:\Users\Dani\anaconda3\lib\site-packages\matplotlib\cbook\deprecation.py", line 411, in wrapper
#     return func(*inner_args, **inner_kwargs)
#   File "C:\Users\Dani\anaconda3\lib\site-packages\matplotlib\axes\_base.py", line 2747, in draw
#     mimage._draw_list_compositing_images(renderer, self, artists)
#   File "C:\Users\Dani\anaconda3\lib\site-packages\matplotlib\image.py", line 131, in _draw_list_compositing_images
#     a.draw(renderer)
#   File "C:\Users\Dani\anaconda3\lib\site-packages\matplotlib\artist.py", line 41, in draw_wrapper
#     return draw(artist, renderer, *args, **kwargs)
#   File "C:\Users\Dani\anaconda3\lib\site-packages\matplotlib\lines.py", line 742, in draw
#     self.recache()
#   File "C:\Users\Dani\anaconda3\lib\site-packages\matplotlib\lines.py", line 662, in recache
#     self._xy = np.column_stack(np.broadcast_arrays(x, y)).astype(float)
#   File "<__array_function__ internals>", line 5, in broadcast_arrays
#   File "C:\Users\Dani\anaconda3\lib\site-packages\numpy\lib\stride_tricks.py", line 538, in broadcast_arrays
#     shape = _broadcast_shape(*args)
#   File "C:\Users\Dani\anaconda3\lib\site-packages\numpy\lib\stride_tricks.py", line 420, in _broadcast_shape
#     b = np.broadcast(*args[:32])
# ValueError: shape mismatch: objects cannot be broadcast to a single shape
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-7-9f328b7dc697> in <module>
#      10     data_int = np.array(struct.unpack(str(CHUNK * 4) + 'B', data), dtype='b')[::2]+127
#      11     line.set_ydata(data_int)
# ---> 12     fig.canvas.draw()
#      13     fig.canvas.flush_events()
#      14
#
# ~\anaconda3\lib\site-packages\matplotlib\backends\backend_tkagg.py in draw(self)
#       7 class FigureCanvasTkAgg(FigureCanvasAgg, FigureCanvasTk):
#       8     def draw(self):
# ----> 9         super(FigureCanvasTkAgg, self).draw()
#      10         _backend_tk.blit(self._tkphoto, self.renderer._renderer, (0, 1, 2, 3))
#      11         self._master.update_idletasks()
#
# ~\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py in draw(self)
#     405              (self.toolbar._wait_cursor_for_draw_cm() if self.toolbar
#     406               else nullcontext()):
# --> 407             self.figure.draw(self.renderer)
#     408             # A GUI class may be need to update a window using this draw, so
#     409             # don't forget to call the superclass.
#
# ~\anaconda3\lib\site-packages\matplotlib\artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      39                 renderer.start_filter()
#      40
# ---> 41             return draw(artist, renderer, *args, **kwargs)
#      42         finally:
#      43             if artist.get_agg_filter() is not None:
#
# ~\anaconda3\lib\site-packages\matplotlib\figure.py in draw(self, renderer)
#    1861
#    1862             self.patch.draw(renderer)
# -> 1863             mimage._draw_list_compositing_images(
#    1864                 renderer, self, artists, self.suppressComposite)
#    1865
#
# ~\anaconda3\lib\site-packages\matplotlib\image.py in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     129     if not_composite or not has_images:
#     130         for a in artists:
# --> 131             a.draw(renderer)
#     132     else:
#     133         # Composite any adjacent images together
#
# ~\anaconda3\lib\site-packages\matplotlib\artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      39                 renderer.start_filter()
#      40
# ---> 41             return draw(artist, renderer, *args, **kwargs)
#      42         finally:
#      43             if artist.get_agg_filter() is not None:
#
# ~\anaconda3\lib\site-packages\matplotlib\cbook\deprecation.py in wrapper(*inner_args, **inner_kwargs)
#     409                          else deprecation_addendum,
#     410                 **kwargs)
# --> 411         return func(*inner_args, **inner_kwargs)
#     412
#     413     return wrapper
#
# ~\anaconda3\lib\site-packages\matplotlib\axes\_base.py in draw(self, renderer, inframe)
#    2745             renderer.stop_rasterizing()
#    2746
# -> 2747         mimage._draw_list_compositing_images(renderer, self, artists)
#    2748
#    2749         renderer.close_group('axes')
#
# ~\anaconda3\lib\site-packages\matplotlib\image.py in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     129     if not_composite or not has_images:
#     130         for a in artists:
# --> 131             a.draw(renderer)
#     132     else:
#     133         # Composite any adjacent images together
#
# ~\anaconda3\lib\site-packages\matplotlib\artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      39                 renderer.start_filter()
#      40
# ---> 41             return draw(artist, renderer, *args, **kwargs)
#      42         finally:
#      43             if artist.get_agg_filter() is not None:
#
# ~\anaconda3\lib\site-packages\matplotlib\lines.py in draw(self, renderer)
#     740
#     741         if self._invalidy or self._invalidx:
# --> 742             self.recache()
#     743         self.ind_offset = 0  # Needed for contains() method.
#     744         if self._subslice and self.axes:
#
# ~\anaconda3\lib\site-packages\matplotlib\lines.py in recache(self, always)
#     660             y = self._y
#     661
# --> 662         self._xy = np.column_stack(np.broadcast_arrays(x, y)).astype(float)
#     663         self._x, self._y = self._xy.T  # views
#     664
#
# <__array_function__ internals> in broadcast_arrays(*args, **kwargs)
#
# ~\anaconda3\lib\site-packages\numpy\lib\stride_tricks.py in broadcast_arrays(subok, *args)
#     536     args = [np.array(_m, copy=False, subok=subok) for _m in args]
#     537
# --> 538     shape = _broadcast_shape(*args)
#     539
#     540     if all(array.shape == shape for array in args):
#
# ~\anaconda3\lib\site-packages\numpy\lib\stride_tricks.py in _broadcast_shape(*args)
#     418     # use the old-iterator because np.nditer does not handle size 0 arrays
#     419     # consistently
# --> 420     b = np.broadcast(*args[:32])
#     421     # unfortunately, it cannot handle 32 or more arguments directly
#     422     for pos in range(32, len(args), 31):
#
# ValueError: shape mismatch: objects cannot be broadcast to a single shape
